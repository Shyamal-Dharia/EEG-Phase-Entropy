# %%
#!/usr/bin/env python3
"""
Pipeline: EEG → 9-level DWT → per-minute segments → 10 s sub-windows (50% overlap) → dPTE  
Per subject, saves NPZ: sub-{ID}_PTE_{group}.npz  
with:
  pte_data: ndarray of shape (n_minutes, n_subwins, n_bands, n_ch, n_ch)
  subject_id: int
"""

import os
import glob
import numpy as np
import mne
import pywt
from scipy.signal import hilbert
import numba as nb

# ───────────── CONFIGURATION ─────────────────────────────────────────────────
MAX_LVL   = 8
WAVELET   = 'db4'
band2levels = {
    'delta': [1,2,3],   # D8–D6 → 0.5–4 Hz
    'theta': [4],       # D5 → 4–8 Hz
    'alpha': [5],       # D4 → 8–16 Hz
    'beta':  [6],       # D3 → 16–32 Hz
    'gamma': [7]        # D2 → 32–64 Hz
}
band_list      = list(band2levels.keys())
MINUTE_LEN     = 60     # seconds per “minute” segment
SUBWIN_LEN     = 10     # seconds per sub-window
OVERLAP        = 0.5    # 50% overlap
DATA_DIR  = "/home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/dataset"
OUT_DIR   = "/home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features"

# ───────────── HELPERS ────────────────────────────────────────────────────────
def get_subject_id(fp: str) -> int:
    for part in fp.split(os.sep):
        if part.startswith('sub-'):
            return int(part.replace('sub-','').strip())
    return None

@nb.njit(fastmath=True, cache=True)
def _entropy(counts, length):
    H = 0.0
    for c in counts:
        if c > 0:
            p = c/length
            H -= p * np.log2(p)
    return H

@nb.njit(fastmath=True, cache=True)
def compute_PTE_numba(phase, delay):
    m,n = phase.shape
    raw = np.zeros((m,m), np.float64)
    L   = n - delay
    for i in range(m):
        x = phase[i,:L]
        for j in range(m):
            y   = phase[j,:L]
            ypr = phase[j,delay:]
            vmax = int(max(x.max(), y.max(), ypr.max()) + 1)
            cnt_y     = np.bincount(y, minlength=vmax)
            idx_ypr_y = ypr + vmax*y
            cnt_ypr_y = np.bincount(idx_ypr_y, minlength=vmax*vmax)
            idx_y_x   = y + vmax*x
            cnt_y_x   = np.bincount(idx_y_x, minlength=vmax*vmax)
            idx_3d    = ypr + vmax*(y + vmax*x)
            cnt_3d    = np.bincount(idx_3d, minlength=vmax*vmax*vmax)
            Hy   = _entropy(cnt_y,   L)
            Hypr = _entropy(cnt_ypr_y,L)
            Hyx  = _entropy(cnt_y_x, L)
            Hyprx= _entropy(cnt_3d,  L)
            raw[i,j] = Hypr + Hyx - Hy - Hyprx
    return raw

@nb.njit(fastmath=True, cache=True)
def dPTE_from_raw(raw):
    sym = raw + raw.T
    return np.triu(raw/sym,1) + np.tril((raw/sym).T,-1)

def reconstruct_band_dwt(data, levels):
    coeffs = pywt.wavedec(data, WAVELET, axis=1, level=MAX_LVL)
    kept   = [np.zeros_like(c) for c in coeffs]
    for lv in levels:
        kept[lv] = coeffs[lv]
    return pywt.waverec(kept, WAVELET, axis=1)

def get_delay(phase):
    m,n = phase.shape
    c1  = m*n
    c2  = (phase * np.roll(phase,1,axis=1) < 0).sum()
    return int(round(c1 / c2))

def get_binsize(phase, c=3.49):
    m,n = phase.shape
    return c * np.mean(np.std(phase,axis=1,ddof=1)) * n**(-1/3)

def discretize_phase(phase, binsz):
    return np.ceil(phase / binsz).astype(np.int32)

# ───────────── PROCESS ONE SUBJECT ────────────────────────────────────────────
def process_one_subject(fp):
    raw = mne.io.read_raw_eeglab(fp, preload=True, verbose='ERROR')
    raw.resample(256)
    fs       = raw.info['sfreq']
    data_full= raw.get_data()           # shape (n_ch, total_samples)
    n_ch     = data_full.shape[0]
    total_samples = data_full.shape[1]

    minute_samples = int(MINUTE_LEN * fs)
    subwin_samples = int(SUBWIN_LEN  * fs)
    step           = int(subwin_samples * (1-OVERLAP))

    # how many full 60 s segments
    n_minutes = total_samples // minute_samples
    n_bands   = len(band_list)
    n_subwins = (minute_samples - subwin_samples)//step + 1  # =11

    # allocate: (n_minutes, n_subwins, n_bands, n_ch, n_ch)
    dp_subject = np.zeros((n_minutes, n_subwins, n_bands, n_ch, n_ch), dtype=np.float64)

    for mi in range(n_minutes):
        seg60 = data_full[:, mi*minute_samples : (mi+1)*minute_samples]
        for bi, band in enumerate(band_list):
            levels = band2levels[band]
            band_data = reconstruct_band_dwt(seg60, levels)
            phase     = np.angle(hilbert(band_data, axis=1))
            delay     = get_delay(phase)
            binsz     = get_binsize(phase)
            dph       = discretize_phase(phase + np.pi, binsz)

            for wi, start in enumerate(range(0, minute_samples - subwin_samples+1, step)):
                blk  = dph[:, start:start+subwin_samples]
                rawP = compute_PTE_numba(blk, delay)
                dp   = dPTE_from_raw(rawP)
                dp_subject[mi, wi, bi, :, :] = dp

    subj_id = get_subject_id(fp)
    return subj_id, dp_subject

# ───────────── MAIN & SAVE ───────────────────────────────────────────────────
if __name__ == '__main__':
    os.makedirs(OUT_DIR, exist_ok=True)

    all_paths = glob.glob(f"{DATA_DIR}/sub-*/eeg/*.set")
    groups    = {'alz':[], 'ctrl':[], 'ftd':[]}
    for fp in all_paths:
        sid = get_subject_id(fp)
        if sid <= 36: groups['alz'].append(fp)
        elif sid <= 65: groups['ctrl'].append(fp)
        else: groups['ftd'].append(fp)

    for grp, paths in groups.items():
        for fp in paths:
            subj_id, dp = process_one_subject(fp)
            out_f = os.path.join(OUT_DIR, f"sub-{subj_id}_PTE_{grp}.npz")
            print(dp.shape)
            np.savez(out_f, pte_data=dp, subject_id=subj_id)
            print(f"Saved {out_f}  shape={dp.shape}")
# Out:
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-2_PTE_alz.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (9, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-30_PTE_alz.npz  shape=(9, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-5_PTE_alz.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-27_PTE_alz.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (9, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-1_PTE_alz.npz  shape=(9, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-17_PTE_alz.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-8_PTE_alz.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-18_PTE_alz.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-32_PTE_alz.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (16, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-16_PTE_alz.npz  shape=(16, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (10, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-9_PTE_alz.npz  shape=(10, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-36_PTE_alz.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-12_PTE_alz.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (11, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-33_PTE_alz.npz  shape=(11, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (11, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-25_PTE_alz.npz  shape=(11, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-13_PTE_alz.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (11, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-4_PTE_alz.npz  shape=(11, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-23_PTE_alz.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (5, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-3_PTE_alz.npz  shape=(5, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-22_PTE_alz.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (16, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-34_PTE_alz.npz  shape=(16, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (15, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-15_PTE_alz.npz  shape=(15, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (15, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-19_PTE_alz.npz  shape=(15, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (12, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-29_PTE_alz.npz  shape=(12, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (12, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-7_PTE_alz.npz  shape=(12, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-26_PTE_alz.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (15, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-21_PTE_alz.npz  shape=(15, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (12, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-24_PTE_alz.npz  shape=(12, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-28_PTE_alz.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (12, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-11_PTE_alz.npz  shape=(12, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (15, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-14_PTE_alz.npz  shape=(15, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-20_PTE_alz.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (19, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-31_PTE_alz.npz  shape=(19, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (10, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-6_PTE_alz.npz  shape=(10, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (12, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-35_PTE_alz.npz  shape=(12, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (21, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-10_PTE_alz.npz  shape=(21, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (12, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-37_PTE_ctrl.npz  shape=(12, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-44_PTE_ctrl.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-49_PTE_ctrl.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (12, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-60_PTE_ctrl.npz  shape=(12, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-63_PTE_ctrl.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-53_PTE_ctrl.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (16, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-42_PTE_ctrl.npz  shape=(16, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-56_PTE_ctrl.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-45_PTE_ctrl.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (16, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-48_PTE_ctrl.npz  shape=(16, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-59_PTE_ctrl.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (12, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-58_PTE_ctrl.npz  shape=(12, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-61_PTE_ctrl.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-65_PTE_ctrl.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-39_PTE_ctrl.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-43_PTE_ctrl.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (16, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-40_PTE_ctrl.npz  shape=(16, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (12, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-52_PTE_ctrl.npz  shape=(12, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-41_PTE_ctrl.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (12, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-51_PTE_ctrl.npz  shape=(12, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-62_PTE_ctrl.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-54_PTE_ctrl.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-64_PTE_ctrl.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-50_PTE_ctrl.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-57_PTE_ctrl.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (12, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-46_PTE_ctrl.npz  shape=(12, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-47_PTE_ctrl.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-38_PTE_ctrl.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-55_PTE_ctrl.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (9, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-85_PTE_ftd.npz  shape=(9, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (11, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-77_PTE_ftd.npz  shape=(11, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-88_PTE_ftd.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-79_PTE_ftd.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (9, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-66_PTE_ftd.npz  shape=(9, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (10, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-67_PTE_ftd.npz  shape=(10, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-73_PTE_ftd.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (9, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-86_PTE_ftd.npz  shape=(9, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (10, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-69_PTE_ftd.npz  shape=(10, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (14, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-78_PTE_ftd.npz  shape=(14, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (10, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-84_PTE_ftd.npz  shape=(10, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (12, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-82_PTE_ftd.npz  shape=(12, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (12, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-75_PTE_ftd.npz  shape=(12, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (10, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-87_PTE_ftd.npz  shape=(10, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-81_PTE_ftd.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (16, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-74_PTE_ftd.npz  shape=(16, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (15, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-83_PTE_ftd.npz  shape=(15, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (13, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-76_PTE_ftd.npz  shape=(13, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (7, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-70_PTE_ftd.npz  shape=(7, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (10, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-72_PTE_ftd.npz  shape=(10, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (10, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-71_PTE_ftd.npz  shape=(10, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (9, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-68_PTE_ftd.npz  shape=(9, 11, 5, 19, 19)
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# (15, 11, 5, 19, 19)
# Saved /home/s.dharia-ra/Shyamal/EEG_Phase_Project/major-revisions/features/sub-80_PTE_ftd.npz  shape=(15, 11, 5, 19, 19)

# %%
import glob
file_paths = glob.glob('./dataset/sub-*/eeg/*.set')

def get_subject_id(filepath):
    for part in filepath.split(os.sep):
        if 'sub-' in part:
            return int(part.replace('sub-', '').strip())
    return None

# Separate into groups
alz_file_paths = []
ctrl_file_paths = []
ftd_file_paths = []

for fpath in file_paths:
    subj_id = get_subject_id(fpath)
    if subj_id is None:
        continue
    if 1 <= subj_id <= 36:
        alz_file_paths.append(fpath)
    elif 37 <= subj_id <= 65:
        ctrl_file_paths.append(fpath)
    elif subj_id >= 66:
        ftd_file_paths.append(fpath)

# %%
#!/usr/bin/env python3
"""
Per‐subject DE extraction via DWT bands, 60 s windows, 50 % overlap over entire recording.
Saves sub-{ID}_DE_{label}.npz with:
  DE_features: ndarray (n_windows, n_channels, n_bands)
  label:       int

Also prints per file:
  • number of windows (1-minute segments) extracted
  • number of channels
  • number of bands (features)
  • shape of the DE_features array
"""

import os
import numpy as np
import mne
import pywt
import math

# ───────────── CONFIG ─────────────────────────────────────────────────────────
MAX_LVL   = 8
WAVELET   = 'db4'
band2levels = {
    'delta': [1,2,3],   # ~0.5–4 Hz
    'theta': [4],       # ~4–8 Hz
    'alpha': [5],       # ~8–12 Hz
    'beta':  [6],       # ~12–30 Hz
    'gamma': [7]        # ~30–45 Hz
}
band_list = list(band2levels.keys())

WIN_LEN  = 60    # window length in seconds
OVERLAP  = 0.0   # 50% overlap
SFREQ    = 256   # target sampling rate (Hz)

# ───────────── HELPERS ────────────────────────────────────────────────────────
def get_subject_id(fp: str) -> int:
    """Extract integer subject ID from a path segment 'sub-##'."""
    for part in fp.split(os.sep):
        if part.startswith('sub-'):
            return int(part.replace('sub-','').strip())
    return None

def reconstruct_band_dwt(data: np.ndarray, levels: list[int]) -> np.ndarray:
    """Perform MAX_LVL‐level DWT and reconstruct only the detail levels in `levels`."""
    coeffs = pywt.wavedec(data, WAVELET, axis=1, level=MAX_LVL)
    kept   = [np.zeros_like(c) for c in coeffs]
    for lv in levels:
        kept[lv] = coeffs[lv]
    return pywt.waverec(kept, WAVELET, axis=1)

def compute_DE(signal: np.ndarray) -> float:
    """Differential entropy: 0.5 * ln(2πe σ²)."""
    var = np.var(signal, ddof=1)
    return 0.5 * math.log(2 * math.pi * math.e * var)

# ───────────── MAIN ───────────────────────────────────────────────────────────
def compute_DE_sliding(files_paths, output_dir, label):
    label_map = {'ctrl':0, 'alz':1, 'ftd':1}
    lbl = label_map.get(label, -1)
    os.makedirs(output_dir, exist_ok=True)

    for fp in files_paths:
        print(f"\n→ Processing {fp}")
        raw = mne.io.read_raw_eeglab(fp, preload=True, verbose='ERROR')
        raw.resample(SFREQ)

        # use full recording
        data = raw.get_data() * 1e6  # (n_ch, n_samples) in µV
        fs, n_ch = int(raw.info['sfreq']), data.shape[0]
        n_samp = data.shape[1]

        # compute window/step in samples
        win  = int(WIN_LEN * fs)
        step = int(win * (1 - OVERLAP))
        # number of windows across full recording
        n_wins = (n_samp - win) // step + 1

        print(f"Number of 60s windows: {n_wins}")
        print(f"Number of channels:    {n_ch}")
        print(f"Number of bands:       {len(band_list)}")

        DE_values = np.zeros((n_wins, n_ch, len(band_list)), dtype=float)

        # sliding windows
        for wi, start in enumerate(range(0, n_samp - win + 1, step)):
            seg = data[:, start:start+win]  # (n_ch, win)
            # band‐specific reconstruction
            band_sigs = {
                band: reconstruct_band_dwt(seg, band2levels[band])
                for band in band_list
            }
            # compute DE per channel & band
            for bi, band in enumerate(band_list):
                sig = band_sigs[band]
                for ch in range(n_ch):
                    DE_values[wi, ch, bi] = compute_DE(sig[ch])

        subj_id = get_subject_id(fp)
        out_file = os.path.join(output_dir, f"sub-{subj_id}_DE_{label}.npz")
        print("DE_values shape:", DE_values.shape)
        np.savez_compressed(out_file,
                            DE_features=DE_values,
                            label=lbl)

        print(f"✔ Saved: {out_file}")
        print(f"  DE_features shape: {DE_values.shape}")

# ───────────── USAGE EXAMPLE ─────────────────────────────────────────────────
if __name__ == '__main__':
    # lists of EEG .set file paths per group

    OUT_DIR = "./DE_results"

    compute_DE_sliding(ctrl_file_paths, OUT_DIR, 'ctrl')
    compute_DE_sliding(alz_file_paths,  OUT_DIR, 'alz')
    compute_DE_sliding(ftd_file_paths,  OUT_DIR, 'ftd')
# Out:
# → Processing ./dataset/sub-037/eeg/sub-037_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 12
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (12, 19, 5)
# ✔ Saved: ./DE_results/sub-37_DE_ctrl.npz
#   DE_features shape: (12, 19, 5)
#
# → Processing ./dataset/sub-044/eeg/sub-044_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-44_DE_ctrl.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-049/eeg/sub-049_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-49_DE_ctrl.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-060/eeg/sub-060_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 12
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (12, 19, 5)
# ✔ Saved: ./DE_results/sub-60_DE_ctrl.npz
#   DE_features shape: (12, 19, 5)
#
# → Processing ./dataset/sub-063/eeg/sub-063_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-63_DE_ctrl.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-053/eeg/sub-053_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-53_DE_ctrl.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-042/eeg/sub-042_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 16
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (16, 19, 5)
# ✔ Saved: ./DE_results/sub-42_DE_ctrl.npz
#   DE_features shape: (16, 19, 5)
#
# → Processing ./dataset/sub-056/eeg/sub-056_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-56_DE_ctrl.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-045/eeg/sub-045_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-45_DE_ctrl.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-048/eeg/sub-048_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 16
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (16, 19, 5)
# ✔ Saved: ./DE_results/sub-48_DE_ctrl.npz
#   DE_features shape: (16, 19, 5)
#
# → Processing ./dataset/sub-059/eeg/sub-059_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-59_DE_ctrl.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-058/eeg/sub-058_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 12
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (12, 19, 5)
# ✔ Saved: ./DE_results/sub-58_DE_ctrl.npz
#   DE_features shape: (12, 19, 5)
#
# → Processing ./dataset/sub-061/eeg/sub-061_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-61_DE_ctrl.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-065/eeg/sub-065_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-65_DE_ctrl.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-039/eeg/sub-039_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-39_DE_ctrl.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-043/eeg/sub-043_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-43_DE_ctrl.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-040/eeg/sub-040_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 16
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (16, 19, 5)
# ✔ Saved: ./DE_results/sub-40_DE_ctrl.npz
#   DE_features shape: (16, 19, 5)
#
# → Processing ./dataset/sub-052/eeg/sub-052_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 12
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (12, 19, 5)
# ✔ Saved: ./DE_results/sub-52_DE_ctrl.npz
#   DE_features shape: (12, 19, 5)
#
# → Processing ./dataset/sub-041/eeg/sub-041_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-41_DE_ctrl.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-051/eeg/sub-051_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 12
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (12, 19, 5)
# ✔ Saved: ./DE_results/sub-51_DE_ctrl.npz
#   DE_features shape: (12, 19, 5)
#
# → Processing ./dataset/sub-062/eeg/sub-062_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-62_DE_ctrl.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-054/eeg/sub-054_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-54_DE_ctrl.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-064/eeg/sub-064_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-64_DE_ctrl.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-050/eeg/sub-050_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-50_DE_ctrl.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-057/eeg/sub-057_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-57_DE_ctrl.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-046/eeg/sub-046_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 12
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (12, 19, 5)
# ✔ Saved: ./DE_results/sub-46_DE_ctrl.npz
#   DE_features shape: (12, 19, 5)
#
# → Processing ./dataset/sub-047/eeg/sub-047_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-47_DE_ctrl.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-038/eeg/sub-038_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-38_DE_ctrl.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-055/eeg/sub-055_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-55_DE_ctrl.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-002/eeg/sub-002_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-2_DE_alz.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-030/eeg/sub-030_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 9
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (9, 19, 5)
# ✔ Saved: ./DE_results/sub-30_DE_alz.npz
#   DE_features shape: (9, 19, 5)
#
# → Processing ./dataset/sub-005/eeg/sub-005_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-5_DE_alz.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-027/eeg/sub-027_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-27_DE_alz.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-001/eeg/sub-001_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 9
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (9, 19, 5)
# ✔ Saved: ./DE_results/sub-1_DE_alz.npz
#   DE_features shape: (9, 19, 5)
#
# → Processing ./dataset/sub-017/eeg/sub-017_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-17_DE_alz.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-008/eeg/sub-008_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-8_DE_alz.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-018/eeg/sub-018_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-18_DE_alz.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-032/eeg/sub-032_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-32_DE_alz.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-016/eeg/sub-016_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 16
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (16, 19, 5)
# ✔ Saved: ./DE_results/sub-16_DE_alz.npz
#   DE_features shape: (16, 19, 5)
#
# → Processing ./dataset/sub-009/eeg/sub-009_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 10
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (10, 19, 5)
# ✔ Saved: ./DE_results/sub-9_DE_alz.npz
#   DE_features shape: (10, 19, 5)
#
# → Processing ./dataset/sub-036/eeg/sub-036_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-36_DE_alz.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-012/eeg/sub-012_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-12_DE_alz.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-033/eeg/sub-033_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 11
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (11, 19, 5)
# ✔ Saved: ./DE_results/sub-33_DE_alz.npz
#   DE_features shape: (11, 19, 5)
#
# → Processing ./dataset/sub-025/eeg/sub-025_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 11
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (11, 19, 5)
# ✔ Saved: ./DE_results/sub-25_DE_alz.npz
#   DE_features shape: (11, 19, 5)
#
# → Processing ./dataset/sub-013/eeg/sub-013_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-13_DE_alz.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-004/eeg/sub-004_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 11
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (11, 19, 5)
# ✔ Saved: ./DE_results/sub-4_DE_alz.npz
#   DE_features shape: (11, 19, 5)
#
# → Processing ./dataset/sub-023/eeg/sub-023_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-23_DE_alz.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-003/eeg/sub-003_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 5
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (5, 19, 5)
# ✔ Saved: ./DE_results/sub-3_DE_alz.npz
#   DE_features shape: (5, 19, 5)
#
# → Processing ./dataset/sub-022/eeg/sub-022_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-22_DE_alz.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-034/eeg/sub-034_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 16
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (16, 19, 5)
# ✔ Saved: ./DE_results/sub-34_DE_alz.npz
#   DE_features shape: (16, 19, 5)
#
# → Processing ./dataset/sub-015/eeg/sub-015_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 15
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (15, 19, 5)
# ✔ Saved: ./DE_results/sub-15_DE_alz.npz
#   DE_features shape: (15, 19, 5)
#
# → Processing ./dataset/sub-019/eeg/sub-019_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 15
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (15, 19, 5)
# ✔ Saved: ./DE_results/sub-19_DE_alz.npz
#   DE_features shape: (15, 19, 5)
#
# → Processing ./dataset/sub-029/eeg/sub-029_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 12
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (12, 19, 5)
# ✔ Saved: ./DE_results/sub-29_DE_alz.npz
#   DE_features shape: (12, 19, 5)
#
# → Processing ./dataset/sub-007/eeg/sub-007_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 12
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (12, 19, 5)
# ✔ Saved: ./DE_results/sub-7_DE_alz.npz
#   DE_features shape: (12, 19, 5)
#
# → Processing ./dataset/sub-026/eeg/sub-026_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-26_DE_alz.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-021/eeg/sub-021_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 15
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (15, 19, 5)
# ✔ Saved: ./DE_results/sub-21_DE_alz.npz
#   DE_features shape: (15, 19, 5)
#
# → Processing ./dataset/sub-024/eeg/sub-024_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 12
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (12, 19, 5)
# ✔ Saved: ./DE_results/sub-24_DE_alz.npz
#   DE_features shape: (12, 19, 5)
#
# → Processing ./dataset/sub-028/eeg/sub-028_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-28_DE_alz.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-011/eeg/sub-011_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 12
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (12, 19, 5)
# ✔ Saved: ./DE_results/sub-11_DE_alz.npz
#   DE_features shape: (12, 19, 5)
#
# → Processing ./dataset/sub-014/eeg/sub-014_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 15
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (15, 19, 5)
# ✔ Saved: ./DE_results/sub-14_DE_alz.npz
#   DE_features shape: (15, 19, 5)
#
# → Processing ./dataset/sub-020/eeg/sub-020_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-20_DE_alz.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-031/eeg/sub-031_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 19
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (19, 19, 5)
# ✔ Saved: ./DE_results/sub-31_DE_alz.npz
#   DE_features shape: (19, 19, 5)
#
# → Processing ./dataset/sub-006/eeg/sub-006_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 10
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (10, 19, 5)
# ✔ Saved: ./DE_results/sub-6_DE_alz.npz
#   DE_features shape: (10, 19, 5)
#
# → Processing ./dataset/sub-035/eeg/sub-035_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 12
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (12, 19, 5)
# ✔ Saved: ./DE_results/sub-35_DE_alz.npz
#   DE_features shape: (12, 19, 5)
#
# → Processing ./dataset/sub-010/eeg/sub-010_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 21
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (21, 19, 5)
# ✔ Saved: ./DE_results/sub-10_DE_alz.npz
#   DE_features shape: (21, 19, 5)
#
# → Processing ./dataset/sub-085/eeg/sub-085_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 9
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (9, 19, 5)
# ✔ Saved: ./DE_results/sub-85_DE_ftd.npz
#   DE_features shape: (9, 19, 5)
#
# → Processing ./dataset/sub-077/eeg/sub-077_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 11
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (11, 19, 5)
# ✔ Saved: ./DE_results/sub-77_DE_ftd.npz
#   DE_features shape: (11, 19, 5)
#
# → Processing ./dataset/sub-088/eeg/sub-088_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-88_DE_ftd.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-079/eeg/sub-079_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-79_DE_ftd.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-066/eeg/sub-066_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 9
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (9, 19, 5)
# ✔ Saved: ./DE_results/sub-66_DE_ftd.npz
#   DE_features shape: (9, 19, 5)
#
# → Processing ./dataset/sub-067/eeg/sub-067_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 10
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (10, 19, 5)
# ✔ Saved: ./DE_results/sub-67_DE_ftd.npz
#   DE_features shape: (10, 19, 5)
#
# → Processing ./dataset/sub-073/eeg/sub-073_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-73_DE_ftd.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-086/eeg/sub-086_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 9
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (9, 19, 5)
# ✔ Saved: ./DE_results/sub-86_DE_ftd.npz
#   DE_features shape: (9, 19, 5)
#
# → Processing ./dataset/sub-069/eeg/sub-069_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 10
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (10, 19, 5)
# ✔ Saved: ./DE_results/sub-69_DE_ftd.npz
#   DE_features shape: (10, 19, 5)
#
# → Processing ./dataset/sub-078/eeg/sub-078_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 14
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (14, 19, 5)
# ✔ Saved: ./DE_results/sub-78_DE_ftd.npz
#   DE_features shape: (14, 19, 5)
#
# → Processing ./dataset/sub-084/eeg/sub-084_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 10
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (10, 19, 5)
# ✔ Saved: ./DE_results/sub-84_DE_ftd.npz
#   DE_features shape: (10, 19, 5)
#
# → Processing ./dataset/sub-082/eeg/sub-082_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 12
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (12, 19, 5)
# ✔ Saved: ./DE_results/sub-82_DE_ftd.npz
#   DE_features shape: (12, 19, 5)
#
# → Processing ./dataset/sub-075/eeg/sub-075_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 12
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (12, 19, 5)
# ✔ Saved: ./DE_results/sub-75_DE_ftd.npz
#   DE_features shape: (12, 19, 5)
#
# → Processing ./dataset/sub-087/eeg/sub-087_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 10
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (10, 19, 5)
# ✔ Saved: ./DE_results/sub-87_DE_ftd.npz
#   DE_features shape: (10, 19, 5)
#
# → Processing ./dataset/sub-081/eeg/sub-081_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-81_DE_ftd.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-074/eeg/sub-074_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 16
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (16, 19, 5)
# ✔ Saved: ./DE_results/sub-74_DE_ftd.npz
#   DE_features shape: (16, 19, 5)
#
# → Processing ./dataset/sub-083/eeg/sub-083_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 15
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (15, 19, 5)
# ✔ Saved: ./DE_results/sub-83_DE_ftd.npz
#   DE_features shape: (15, 19, 5)
#
# → Processing ./dataset/sub-076/eeg/sub-076_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 13
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (13, 19, 5)
# ✔ Saved: ./DE_results/sub-76_DE_ftd.npz
#   DE_features shape: (13, 19, 5)
#
# → Processing ./dataset/sub-070/eeg/sub-070_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 7
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (7, 19, 5)
# ✔ Saved: ./DE_results/sub-70_DE_ftd.npz
#   DE_features shape: (7, 19, 5)
#
# → Processing ./dataset/sub-072/eeg/sub-072_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 10
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (10, 19, 5)
# ✔ Saved: ./DE_results/sub-72_DE_ftd.npz
#   DE_features shape: (10, 19, 5)
#
# → Processing ./dataset/sub-071/eeg/sub-071_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 10
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (10, 19, 5)
# ✔ Saved: ./DE_results/sub-71_DE_ftd.npz
#   DE_features shape: (10, 19, 5)
#
# → Processing ./dataset/sub-068/eeg/sub-068_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 9
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (9, 19, 5)
# ✔ Saved: ./DE_results/sub-68_DE_ftd.npz
#   DE_features shape: (9, 19, 5)
#
# → Processing ./dataset/sub-080/eeg/sub-080_task-eyesclosed_eeg.set
# joblib supports memapping pool but "MNE_CACHE_DIR" is not set in MNE-Python config. To enable it, use, e.g., mne.set_cache_dir('/tmp/shm'). This will store temporary files under /dev/shm and can result in large memory savings.
# Number of 60s windows: 15
# Number of channels:    19
# Number of bands:       5
# DE_values shape: (15, 19, 5)
# ✔ Saved: ./DE_results/sub-80_DE_ftd.npz
#   DE_features shape: (15, 19, 5)
